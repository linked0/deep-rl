# %% [markdown]
# <a href="https://colab.research.google.com/github/linked0/deep-rl/blob/master/temporal-difference/Temporal_Difference_181121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# start
